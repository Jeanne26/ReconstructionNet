# %%
from model import ReconstructionNet
from torchsummary import summary
import torch

# %%
model = ReconstructionNet(64,5)
print(summary(model,(2,64)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─ModuleList: 1                          []                        --
# |    └─AutoEncoder: 2-1                  [-1, 2, 64]               --
# |    |    └─Encoder: 3-1                 [-1, 2, 1]                2,793
# |    |    └─Decoder: 3-2                 [-1, 2, 64]               2,856
# ├─ModuleList: 1                          []                        --
# |    └─Linear: 2-2                       [-1, 2, 1]                65
# ├─ModuleList: 1                          []                        --
# |    └─AutoEncoder: 2-3                  [-1, 2, 64]               --
# |    |    └─Encoder: 3-3                 [-1, 2, 1]                2,793
# |    |    └─Decoder: 3-4                 [-1, 2, 64]               2,856
# ├─ModuleList: 1                          []                        --
# |    └─Linear: 2-4                       [-1, 2, 1]                65
# ├─ModuleList: 1                          []                        --
# |    └─AutoEncoder: 2-5                  [-1, 2, 64]               --
# |    |    └─Encoder: 3-5                 [-1, 2, 1]                2,793
# |    |    └─Decoder: 3-6                 [-1, 2, 64]               2,856
# ├─ModuleList: 1                          []                        --
# |    └─Linear: 2-6                       [-1, 2, 1]                65
# ├─ModuleList: 1                          []                        --
# |    └─AutoEncoder: 2-7                  [-1, 2, 64]               --
# |    |    └─Encoder: 3-7                 [-1, 2, 1]                2,793
# |    |    └─Decoder: 3-8                 [-1, 2, 64]               2,856
# ├─ModuleList: 1                          []                        --
# |    └─Linear: 2-8                       [-1, 2, 1]                65
# ├─ModuleList: 1                          []                        --
# |    └─AutoEncoder: 2-9                  [-1, 2, 64]               --
# |    |    └─Encoder: 3-9                 [-1, 2, 1]                2,793
# |    |    └─Decoder: 3-10                [-1, 2, 64]               2,856
# ├─ModuleList: 1                          []                        --
# |    └─Linear: 2-10                      [-1, 2, 1]                65
# ==========================================================================================
# Total params: 28,570
# Trainable params: 28,570
# Non-trainable params: 0
# Total mult-adds (M): 0.08
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.11
# Estimated Total Size (MB): 0.11
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─ModuleList: 1                          []                        --
# |    └─AutoEncoder: 2-1                  [-1, 2, 64]               --
# |    |    └─Encoder: 3-1                 [-1, 2, 1]                2,793
# |    |    └─Decoder: 3-2                 [-1, 2, 64]               2,856
# ├─ModuleList: 1                          []                        --
# |    └─Linear: 2-2                       [-1, 2, 1]                65
# ├─ModuleList: 1                          []                        --
# |    └─AutoEncoder: 2-3                  [-1, 2, 64]               --
# |    |    └─Encoder: 3-3                 [-1, 2, 1]                2,793
# |    |    └─Decoder: 3-4                 [-1, 2, 64]               2,856
# ├─ModuleList: 1                          []                        --
# |    └─Linear: 2-4                       [-1, 2, 1]                65
# ├─ModuleList: 1                          []                        --
# |    └─AutoEncoder: 2-5                  [-1, 2, 64]               --
# |    |    └─Encoder: 3-5                 [-1, 2, 1]                2,793
# |    |    └─Decoder: 3-6                 [-1, 2, 64]               2,856
# ├─ModuleList: 1                          []                        --
# |    └─Linear: 2-6                       [-1, 2, 1]                65
# ├─ModuleList: 1                          []                        --
# |    └─AutoEncoder: 2-7                  [-1, 2, 64]               --
# |    |    └─Encoder: 3-7                 [-1, 2, 1]                2,793
# |    |    └─Decoder: 3-8                 [-1, 2, 64]               2,856
# ├─ModuleList: 1                          []                        --
# |    └─Linear: 2-8                       [-1, 2, 1]                65
# ├─ModuleList: 1                          []                        --
# |    └─AutoEncoder: 2-9                  [-1, 2, 64]               --
# |    |    └─Encoder: 3-9                 [-1, 2, 1]                2,793
# |    |    └─Decoder: 3-10                [-1, 2, 64]               2,856
# ├─ModuleList: 1                          []                        --
# |    └─Linear: 2-10                      [-1, 2, 1]                65
# ==========================================================================================
# Total params: 28,570
# Trainable params: 28,570
# Non-trainable params: 0
# Total mult-adds (M): 0.08
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.11
# Estimated Total Size (MB): 0.11
# ==========================================================================================

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter("runs/ReconstructionNet")

input = torch.randn(1,64)

writer.add_graph(model, input)
writer.close()
# Out:
# /home/jeanne/M2/.venv/lib/python3.11/site-packages/torch/jit/_trace.py:1282: TracerWarning: Encountering a list at the output of the tracer might cause the trace to be incorrect, this is only valid if the container structure does not change based on the module's inputs. Consider using a constant container instead (e.g. for `list`, use a `tuple` instead. for `dict`, use a `NamedTuple` instead). If you absolutely need this and know the side effects, pass strict=False to trace() to allow this behavior.
#   module._c._create_method_from_trace(
